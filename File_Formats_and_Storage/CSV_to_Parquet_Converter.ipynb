# %%
import pandas as pd
import os

dataframe = pd.read_csv("/Users/fredikamionka/PycharmProjects/Projects_for_CV/Files_Project_for_CV/Full.csv")

print(dataframe.dtypes)

dataframe.to_parquet("/Users/fredikamionka/PycharmProjects/Projects_for_CV/Files_Project_for_CV/data.parquet", compression="snappy")

display(f"size df: {os.path.getsize('/Users/fredikamionka/PycharmProjects/Projects_for_CV/Files_Project_for_CV/Full.csv')}")

display(f"size parqet: {os.path.getsize("/Users/fredikamionka/PycharmProjects/Projects_for_CV/Files_Project_for_CV/data.parquet")}")
# Out:
# ID_x            int64
# OrderID         int64
# Client_ID       int64
# Product_ID      int64
# QTY             int64
# DataStamp         str
# Day             int64
# Month           int64
# Year            int64
# First             str
# Last              str
# District          str
# ID_y            int64
# Name              str
# Price         float64
# Unit(g)         int64
# dtype: object
# 'size df: 3387631'
# 'size parqet: 1226822'
