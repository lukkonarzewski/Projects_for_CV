# %%
import pandas as pd
import os
# Out:
#   Cell In[4], line 3
#     pip install pyarrow
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import os

dataframe = pd.read_csv("/Users/fredikamionka/PycharmProjects/Projects_for_CV/Files_Project_for_CV/Full.csv")

print(dataframe.dtypes)

dataframe.to_parquet("/Users/fredikamionka/PycharmProjects/Projects_for_CV/Files_Project_for_CV/data.parquet", compression="snappy")

print(os.path.getsize("data.csv"))
print(os.path.getsize("data.parquet"))
# Out:
# ID_x            int64
# OrderID         int64
# Client_ID       int64
# Product_ID      int64
# QTY             int64
# DataStamp         str
# Day             int64
# Month           int64
# Year            int64
# First             str
# Last              str
# District          str
# ID_y            int64
# Name              str
# Price         float64
# Unit(g)         int64
# dtype: object
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 8
#       4 dataframe = pd.read_csv("/Users/fredikamionka/PycharmProjects/Projects_for_CV/Files_Project_for_CV/Full.csv")
#       5
#       6 print(dataframe.dtypes)
#       7
# ----> 8 dataframe.to_parquet("/Users/fredikamionka/PycharmProjects/Projects_for_CV/Files_Project_for_CV/data.parquet", compression="snappy")
#       9
#      10 print(os.path.getsize("data.csv"))
#      11 print(os.path.getsize("data.parquet"))
#
# ...
